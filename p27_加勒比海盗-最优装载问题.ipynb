# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def greedy1():
    w = [2,3,4,5,7,10,11,14]
    w = sorted(w)
    
    temp = 0
    for idx, v in enumerate(w):
        temp += v
        if temp > 30:
            break
    return temp, idx

# %%
greedy1()
# Out:
# (31, 5)
